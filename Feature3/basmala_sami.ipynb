# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\norah\Downloads\titanic_data.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 884         0       2    male  27.0      0      0  13.0000        S  Second
# 885         1       1  female  19.0      0      0  30.0000        S   First
# 886         0       3  female   NaN      1      2  23.4500        S   Third
# 887         1       1    male  26.0      0      0  30.0000        C   First
# 888         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.drop(df[df['fare']>140].index, axis = 0, inplace =True)

# %%
sns.set_palette('Set3')
bp = sns.boxplot(data = df, x = "fare",color='skyblue')
plt.show()
sp = sns.scatterplot(data = df, x = "fare", y=df["survived"],color='skyblue')
plt.show()

# %%
# Calculate the mean and standard deviation of the column
mean_col = df['fare'].mean()
std_col = df['fare'].std()

# %%
# Calculate the upper and lower limits
upper_limit = mean_col + 3 * std_col
lower_limit = mean_col - 3 * std_col

# %%
# Print the results
print("Upper limit: ",upper_limit)
print("Lower limit: ",lower_limit)
df_outliers = df.loc[(df['fare'] > upper_limit) | (df['fare'] < lower_limit)]
df_outliers
# Out:
# Upper limit:  102.22707548431507
# Lower limit:  -52.33716849130807
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 214         1       1  female  31.0      1      0  113.2750        C  First
# 268         1       1  female  35.0      0      0  135.6333        S  First
# 305         1       1  female   NaN      0      0  110.8833        C  First
# 306         1       1  female  17.0      1      0  108.9000        C  First
# 318         1       1  female  40.0      1      1  134.5000        C  First
# 324         1       1  female  36.0      0      0  135.6333        C  First
# 333         1       1  female   NaN      1      0  133.6500        S  First
# 336         1       1  female  41.0      0      0  134.5000        C  First
# 372         0       1    male  22.0      0      0  135.6333        C  First
# 389         1       1    male  36.0      1      2  120.0000        S  First
# ...
